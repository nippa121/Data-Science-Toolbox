# %% [markdown]
# <a href="https://colab.research.google.com/github/nippa121/Data-Science-Toolbox/blob/master/SHAWNA's_CRUNCHER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Shawna's Cruncher, a nimble and astute piece of software, emerges as a beacon for those navigating the vast
# and often tumultuous seas of digital documents. Crafted with the precision of a master artisan, it effortlessly
# bridges the chasm between diverse document formats—PDFs, Word documents, and CSV files, translating their
# contents into a singular, coherent form. At its core, Shawna's Cruncher beckons users to whisper their queries,
# their digital desires, into its ear, whereupon it consults the vast intellect of OpenAI's GPT-4, melding the
# extracted text with user instructions to forge a response not just insightful but tailored, as if each word were
# meticulously picked from the digital ether. This alchemy doesn't end in the ephemeral; Shawna's Cruncher
# crystallizes its insights into PDFs, offering them as tangible tokens of wisdom, easily downloadable and forever
# a testament to the user's inquiry, a digital alchemist turning the lead of raw data into the gold of knowledge.
# Well, anyway--it summarizes PDF files per a user's prompt--more or less.

# Here, we're installing the necessary libararies of code to make this work--OpenAI's libaray is a big part.


# !pip install openai==0.28
# !pip install openai pymupdf python-docx pandas
import openai

# %%
# In a world swamped with documents of varying formats—each with its own peculiarities and quirks,
# imagine a Python script, a veritable Swiss Army knife for the digital age, deftly handling PDFs,
# Word docs, and CSV files alike. This script, with the discernment of a seasoned librarian, extracts text,
# weaving through the digital labyrinth to fetch the essence contained within these files, prompted by
# user queries that span the gamut of curiosity. It then consults the oracle, OpenAI's GPT-4, merging
# the user's quest with the extracted text to form a question that's both precise and expansive, seeking
# insights hidden in the folds of digital text. Finally, this alchemical mixture of text and insight is
# transmuted into a PDF, a tangible artifact of this inquiry, ready to be downloaded, a digital breadcrumb
# trail leading back to the user's initial wonder.

#Code to extract text and define df_1
import fitz  # PyMuPDF
from docx import Document
import pandas as pd
import io

def extract_text(file_name, content):
    if file_name.lower().endswith('.pdf'):
        with fitz.open(stream=content, filetype="pdf") as doc:
            text = " ".join(page.get_text() for page in doc)
    elif file_name.lower().endswith('.docx'):
        doc = Document(io.BytesIO(content))
        text = " ".join(paragraph.text for paragraph in doc.paragraphs)
    elif file_name.lower().endswith('.csv'):
        df = pd.read_csv(io.BytesIO(content))
        text = df.to_csv(index=False)
    else:
        raise ValueError("Unsupported file type.")
    return text

file_name, content = upload_or_fetch()  # Ensure this function is defined and called before
document_text = extract_text(file_name, content)


user_instructions = input("What do you want to do with this document? ")

# Ensure your API key is correctly set
openai.api_key = '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'

document_text  # Assuming df_1 contains the extracted text from the user-submitted document
user_instructions # Assuming df_2 is the user's prompt or instructions about that document

def ask_gpt_4_about_document(document_text, user_instructions):
    # Prepare the prompt combining both the document text and the user instructions
    combined_prompt = f"Document content:\n{document_text}\n\nUser's instructions or questions about the document:\n{user_instructions}"

    # Send the prompt to GPT-4 using the Chat Completion endpoint
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant that provides insights and answers about documents."},
            {"role": "user", "content": combined_prompt}
        ]
    )

    # Extract and return the response text
    return response.choices[0].message['content']

response_text = ask_gpt_4_about_document(document_text, user_instructions)
print(response_text)



# Assuming the rest of your code (PDF generation, etc.) is above this point

# Save the PDF in Colab's file system
pdf_path = save_response_as_pdf(response_text, filename="/content/gpt_response.pdf")

# Now prompt the user to download the PDF to their local machine
from google.colab import files
files.download(pdf_path)
# Out:
# Upload a file or enter a URL (type 'upload' or 'url'): upload
#      <input type="file" id="files-6923d6dc-c258-4a1e-89a9-3648139a51e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6923d6dc-c258-4a1e-89a9-3648139a51e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
